# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv("AdmissionPredict.csv")
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1      337.0        118.0                  4  4.5   4.5  9.65
# 1           2      324.0        107.0                  4  4.0   4.5  8.87
# 2           3      316.0          NaN                  3  3.0   3.5  8.00
# 3           4        NaN        110.0                  3  3.5   2.5  8.67
# 4           5      314.0        103.0                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1              NaN
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
data.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 395         396      324.0        110.0                  3  3.5   3.5  9.04
# 396         397      325.0        107.0                  3  3.0   3.5  9.11
# 397         398      330.0        116.0                  4  5.0   4.5  9.45
# 398         399      312.0        103.0                  3  3.5   4.0  8.78
# 399         400      333.0        117.0                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 395         1             0.82
# 396         1              NaN
# 397         1             0.91
# 398         0             0.67
# 399         1             0.95

# %%
data.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  378.000000   380.000000         400.000000  400.000000
# mean   200.500000  316.759259   107.386842           3.087500    3.400000
# std    115.614301   11.415599     6.048645           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.250000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  380.000000  400.000000       384.000000
# mean     3.452500    8.604737    0.547500         0.724375
# std      0.898478    0.599167    0.498362         0.142964
# min      1.000000    6.800000    0.000000         0.340000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
# Serial No.           400 non-null int64
# GRE Score            378 non-null float64
# TOEFL Score          380 non-null float64
# University Rating    400 non-null int64
# SOP                  400 non-null float64
# LOR                  400 non-null float64
# CGPA                 380 non-null float64
# Research             400 non-null int64
# Chance of Admit      384 non-null float64
# dtypes: float64(6), int64(3)
# memory usage: 28.2 KB

# %%
data.isnull().sum()
# Out:
# Serial No.            0
# GRE Score            22
# TOEFL Score          20
# University Rating     0
# SOP                   0
# LOR                   0
# CGPA                 20
# Research              0
# Chance of Admit      16
# dtype: int64

# %%
data.dtypes
# Out:
# Serial No.             int64
# GRE Score            float64
# TOEFL Score          float64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %%
data["GRE Score"].mean()
# Out:
# 316.75925925925924

# %%
data["TOEFL Score"].mean()
# Out:
# 107.38684210526316

# %%
data["CGPA"].mean()
# Out:
# 8.604736842105263

# %%
data.isnull().sum()
# Out:
# Serial No.            0
# GRE Score            22
# TOEFL Score          20
# University Rating     0
# SOP                   0
# LOR                   0
# CGPA                 20
# Research              0
# Chance of Admit      16
# dtype: int64

# %%
data["GRE Score"].fillna(data["GRE Score"].mean().astype(int), inplace = True)

# %%
data["TOEFL Score"].fillna(data["TOEFL Score"].mean().astype(int), inplace = True)

# %%
data["CGPA"].fillna(data["CGPA"].mean(), inplace = True)

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   \
# 0             1      337.0        118.0                  4  4.5   4.5
# 1             2      324.0        107.0                  4  4.0   4.5
# 2             3      316.0        107.0                  3  3.0   3.5
# 3             4      316.0        110.0                  3  3.5   2.5
# 4             5      314.0        103.0                  2  2.0   3.0
# 5             6      330.0        115.0                  5  4.5   3.0
# 6             7      321.0        109.0                  3  3.0   4.0
# 7             8      308.0        101.0                  2  3.0   4.0
# 8             9      302.0        102.0                  1  2.0   1.5
# 9            10      323.0        108.0                  3  3.5   3.0
# 10           11      325.0        106.0                  3  3.5   4.0
# 11           12      316.0        111.0                  4  4.0   4.5
# ...

# %%
data.isnull().sum()
# Out:
# Serial No.            0
# GRE Score             0
# TOEFL Score           0
# University Rating     0
# SOP                   0
# LOR                   0
# CGPA                  0
# Research              0
# Chance of Admit      16
# dtype: int64

# %%
data["GRE Score"]
# Out:
# 0      337.0
# 1      324.0
# 2      316.0
# 3      316.0
# 4      314.0
# 5      330.0
# 6      321.0
# 7      308.0
# 8      302.0
# 9      323.0
# 10     325.0
# 11     316.0
# 12     328.0
# 13     307.0
# 14     311.0
# 15     314.0
# 16     317.0
# 17     319.0
# 18     318.0
# 19     303.0
# 20     312.0
# 21     325.0
# 22     328.0
# 23     334.0
# 24     336.0
# 25     340.0
# 26     322.0
# 27     298.0
# 28     295.0
# 29     310.0
#        ...
# 370    310.0
# 371    324.0
# 372    336.0
# 373    321.0
# 374    315.0
# 375    304.0
# 376    297.0
# 377    290.0
# 378    303.0
# 379    311.0
# 380    322.0
# 381    319.0
# 382    324.0
# 383    300.0
# 384    316.0
# 385    316.0
# 386    302.0
# 387    307.0
# 388    296.0
# 389    320.0
# 390    314.0
# 391    318.0
# 392    326.0
# 393    317.0
# 394    329.0
# 395    324.0
# 396    325.0
# 397    330.0
# 398    312.0
# 399    333.0
# Name: GRE Score, Length: 400, dtype: float64

# %%
data["TOEFL Score"]
# Out:
# 0      118.0
# 1      107.0
# 2      107.0
# 3      110.0
# 4      103.0
# 5      115.0
# 6      109.0
# 7      101.0
# 8      102.0
# 9      108.0
# 10     106.0
# 11     111.0
# 12     112.0
# 13     109.0
# 14     104.0
# 15     105.0
# 16     107.0
# 17     106.0
# 18     110.0
# 19     102.0
# 20     107.0
# 21     114.0
# 22     116.0
# 23     119.0
# 24     119.0
# 25     120.0
# 26     109.0
# 27     107.0
# 28      93.0
# 29      99.0
#        ...
# 370    103.0
# 371    110.0
# 372    107.0
# 373    109.0
# 374    105.0
# 375    101.0
# 376     96.0
# 377    100.0
# 378     98.0
# 379     99.0
# 380    104.0
# 381    105.0
# 382    110.0
# 383    100.0
# 384    113.0
# 385    117.0
# 386    101.0
# 387    105.0
# 388     97.0
# 389    108.0
# 390    102.0
# 391    106.0
# 392    112.0
# 393    104.0
# 394    111.0
# 395    110.0
# 396    107.0
# 397    116.0
# 398    103.0
# 399    117.0
# Name: TOEFL Score, Length: 400, dtype: float64

# %%
data["CGPA"]
# Out:
# 0      9.650000
# 1      8.870000
# 2      8.000000
# 3      8.670000
# 4      8.210000
# 5      9.340000
# 6      8.604737
# 7      7.900000
# 8      8.000000
# 9      8.600000
# 10     8.400000
# 11     9.000000
# 12     9.100000
# 13     8.000000
# 14     8.200000
# 15     8.300000
# 16     8.700000
# 17     8.000000
# 18     8.800000
# 19     8.500000
# 20     7.900000
# 21     8.400000
# 22     9.500000
# 23     9.700000
# 24     9.800000
# 25     9.600000
# 26     8.800000
# 27     8.604737
# 28     7.200000
# 29     7.300000
#          ...
# 370    8.240000
# 371    9.220000
# 372    9.620000
# 373    8.540000
# 374    7.650000
# 375    7.660000
# 376    7.430000
# 377    7.560000
# 378    7.650000
# 379    8.430000
# 380    8.840000
# 381    8.670000
# 382    9.150000
# 383    8.260000
# 384    9.740000
# 385    9.820000
# 386    7.960000
# 387    8.100000
# 388    7.800000
# 389    8.440000
# 390    8.240000
# 391    8.650000
# 392    8.604737
# 393    8.760000
# ...

# %%
plt.scatter(data["GRE Score"], data["Chance of Admit"], color = 'r')
plt.title('Efficacy of GRE Score')
plt.xlabel('GRE Score')
plt.ylabel('Chance of Admit')
# Out:
# Text(0,0.5,'Chance of Admit')

# %%
plt.scatter(data["TOEFL Score"], data["Chance of Admit"], color = 'b')
plt.title('Efficacy of TOEFL Score')
plt.xlabel('TOEFL Score')
plt.ylabel('Chance of Admit')
# Out:
# Text(0,0.5,'Chance of Admit')

# %%
plt.scatter(data["University Rating"], data["Chance of Admit"], color = 'y')
plt.title('Efficacy of University Rating')
plt.xlabel('University Rating')
plt.ylabel('Chance of Admit')
# Out:
# Text(0,0.5,'Chance of Admit')

# %%
plt.scatter(data["SOP"], data["Chance of Admit"], color = 'g')
plt.title('Efficacy of SOP')
plt.xlabel('SOP')
plt.ylabel('Chance of Admit')
# Out:
# Text(0,0.5,'Chance of Admit')

# %%
plt.scatter(data["CGPA"], data["Chance of Admit"], color = (0,0,0))
plt.title('Efficacy of CGPA')
plt.xlabel('CGPA')
plt.ylabel('Chance of Admit')
# Out:
# Text(0,0.5,'Chance of Admit')

# %%
plt.scatter(data["Research"], data["Chance of Admit"], color = 'c')
plt.title('Efficacy of Research')
plt.xlabel('Research')
plt.ylabel('Chance of Admit')
# Out:
# Text(0,0.5,'Chance of Admit')

# %%
plt.scatter(data["LOR "], data["Chance of Admit"], color = 'r')
plt.title('Efficacy of LOR')
plt.xlabel('LOR')
plt.ylabel('Chance of Admit')
# Out:
# Text(0,0.5,'Chance of Admit')

# %%
data[(data["CGPA"] >= 9) & (data["TOEFL Score"] >= 110)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1      337.0        118.0                  4  4.5   4.5  9.65
# 5             6      330.0        115.0                  5  4.5   3.0  9.34
# 11           12      316.0        111.0                  4  4.0   4.5  9.00
# 12           13      328.0        112.0                  4  4.0   4.5  9.10
# 22           23      328.0        116.0                  5  5.0   5.0  9.50
# 23           24      334.0        119.0                  5  5.0   4.5  9.70
# 24           25      336.0        119.0                  5  4.0   3.5  9.80
# 25           26      340.0        120.0                  5  4.5   4.5  9.60
# 32           33      338.0        118.0                  4  3.0   4.5  9.40
# 33           34      340.0        114.0                  5  4.0   4.0  9.60
# 34           35      331.0        112.0                  5  4.0   5.0  9.80
# ...

# %%
data[(data["CGPA"] >= 9) & (data["TOEFL Score"] >= 110)].count()
# Out:
# Serial No.           97
# GRE Score            97
# TOEFL Score          97
# University Rating    97
# SOP                  97
# LOR                  97
# CGPA                 97
# Research             97
# Chance of Admit      95
# dtype: int64

# %%
groups = data.groupby("University Rating")
groups["GRE Score"].mean()
# Out:
# University Rating
# 1    303.153846
# 2    309.710280
# 3    315.894737
# 4    324.013514
# 5    327.916667
# Name: GRE Score, dtype: float64

# %%
plt.scatter(data["CGPA"], data["Chance of Admit"], color = (0,0,0))
plt.title('Efficacy of CGPA')
plt.xlabel('CGPA')
plt.ylabel('Chance of Admit')
# Out:
# Text(0,0.5,'Chance of Admit')

# %% [markdown]
# ##i chose cgpa as the most important requierment
# چون همانطور معدل که افزایش میابد، شانس پذیرش نیز افزایش میابد.
# هم چنین در مواردی که معدل از 9.5 بیشتر است، به خصوص در مواردی که نزدیک به 10 میباشد، شانس پذیرش به بالاترین مقدار نزدیک میشود و استثنایی هم برای آن وجود ندارد و همچنین در تمامی این موارد، شانس پذیرش با افزایش معدل به 1 نزدیک میشود.

# %%
newData = data[['CGPA', 'Chance of Admit']].copy()
secondData = data[['CGPA', 'Chance of Admit']].copy()
newData
# Out:
#          CGPA  Chance of Admit
# 0    9.650000             0.92
# 1    8.870000              NaN
# 2    8.000000             0.72
# 3    8.670000             0.80
# 4    8.210000             0.65
# 5    9.340000             0.90
# 6    8.604737             0.75
# 7    7.900000             0.68
# 8    8.000000             0.50
# 9    8.600000             0.45
# 10   8.400000             0.52
# 11   9.000000             0.84
# 12   9.100000             0.78
# 13   8.000000             0.62
# 14   8.200000             0.61
# 15   8.300000             0.54
# 16   8.700000             0.66
# 17   8.000000             0.65
# 18   8.800000             0.63
# 19   8.500000             0.62
# 20   7.900000             0.64
# 21   8.400000             0.70
# 22   9.500000             0.94
# 23   9.700000             0.95
# 24   9.800000             0.97
# 25   9.600000             0.94
# 26   8.800000             0.76
# 27   8.604737             0.44
# 28   7.200000             0.46
# ...

# %%
newData["Chance of Admit"].notnull()
index = newData["Chance of Admit"].notnull()
newData = newData[index]
newData
# Out:
#          CGPA  Chance of Admit
# 0    9.650000             0.92
# 2    8.000000             0.72
# 3    8.670000             0.80
# 4    8.210000             0.65
# 5    9.340000             0.90
# 6    8.604737             0.75
# 7    7.900000             0.68
# 8    8.000000             0.50
# 9    8.600000             0.45
# 10   8.400000             0.52
# 11   9.000000             0.84
# 12   9.100000             0.78
# 13   8.000000             0.62
# 14   8.200000             0.61
# 15   8.300000             0.54
# 16   8.700000             0.66
# 17   8.000000             0.65
# 18   8.800000             0.63
# 19   8.500000             0.62
# 20   7.900000             0.64
# 21   8.400000             0.70
# 22   9.500000             0.94
# 23   9.700000             0.95
# 24   9.800000             0.97
# 25   9.600000             0.94
# 26   8.800000             0.76
# 27   8.604737             0.44
# 28   7.200000             0.46
# 29   7.300000             0.54
# ...

# %%
index = secondData["Chance of Admit"].notnull()
index2 = ~index
secondData = secondData[index2]
secondData
# Out:
#      CGPA  Chance of Admit
# 1    8.87              NaN
# 57   7.60              NaN
# 135  8.77              NaN
# 143  9.92              NaN
# 171  9.07              NaN
# 218  8.97              NaN
# 232  8.27              NaN
# 251  9.00              NaN
# 272  7.64              NaN
# 294  8.32              NaN
# 315  8.07              NaN
# 338  8.74              NaN
# 357  7.89              NaN
# 381  8.67              NaN
# 390  8.24              NaN
# 396  9.11              NaN

# %%
plt.scatter(data["CGPA"], data["Chance of Admit"], color = (0,0,0))
plt.title('Efficacy of CGPA')
plt.xlabel('CGPA')
plt.ylabel('Chance of Admit')
plt.plot(data["CGPA"], 0.18*data["CGPA"] - 0.784)

# %%
s = ((0.18*newData["CGPA"] - 0.784) - newData["Chance of Admit"])**2

s = s.sum()
s = s/800
s
# Out:
# 0.0035600920192520734

# %%
secondData["Chance of Admit"] = 0.18*secondData["CGPA"] - 0.784
secondData.index
# Out:
# Int64Index([1, 57, 135, 143, 171, 218, 232, 251, 272, 294, 315, 338, 357, 381,
#             390, 396],
#            dtype='int64')

# %%
data["Chance of Admit"][secondData.index] = 0.18*secondData["CGPA"] - 0.784
data.iloc[secondData.index]
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 1             2      324.0        107.0                  4  4.0   4.5  8.87
# 57           58      298.0         99.0                  2  4.0   2.0  7.60
# 135         136      314.0        109.0                  4  3.5   4.0  8.77
# 143         144      340.0        120.0                  4  4.5   4.0  9.92
# 171         172      316.0        117.0                  5  4.0   4.5  9.07
# 218         219      324.0        110.0                  4  3.0   3.5  8.97
# 232         233      312.0        107.0                  2  2.5   3.5  8.27
# ...

# %%
a = np.isin(data.index,secondData.index)
data[a]["Chance of Admit"] = 2
data[a]
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 1             2      324.0        107.0                  4  4.0   4.5  8.87
# 57           58      298.0         99.0                  2  4.0   2.0  7.60
# 135         136      314.0        109.0                  4  3.5   4.0  8.77
# 143         144      340.0        120.0                  4  4.5   4.0  9.92
# 171         172      316.0        117.0                  5  4.0   4.5  9.07
# 218         219      324.0        110.0                  4  3.0   3.5  8.97
# 232         233      312.0        107.0                  2  2.5   3.5  8.27
# ...

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   \
# 0             1      337.0        118.0                  4  4.5   4.5
# 1             2      324.0        107.0                  4  4.0   4.5
# 2             3      316.0        107.0                  3  3.0   3.5
# 3             4      316.0        110.0                  3  3.5   2.5
# 4             5      314.0        103.0                  2  2.0   3.0
# 5             6      330.0        115.0                  5  4.5   3.0
# 6             7      321.0        109.0                  3  3.0   4.0
# 7             8      308.0        101.0                  2  3.0   4.0
# 8             9      302.0        102.0                  1  2.0   1.5
# 9            10      323.0        108.0                  3  3.5   3.0
# 10           11      325.0        106.0                  3  3.5   4.0
# 11           12      316.0        111.0                  4  4.0   4.5
# ...
